# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os


load_dotenv()

model = ChatGoogleGenerativeAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    model="gemini-3-flash-preview"
    )

# %%
res =  model.invoke("Quibts theory")

# %%
res.content[0]["text"]
# Out:
# 'It appears you are referring to **Qubit Theory** (Quantum Bits). \n\nIn classical computing, the basic unit of information is a **bit**, which can be either a 0 or a 1. In quantum computing, the basic unit is a **qubit**, which operates under the laws of quantum mechanics.\n\nHere is a breakdown of the core principles of Qubit Theory:\n\n---\n\n### 1. Superposition\nWhile a classical bit is like a light switch (either On or Off), a qubit is like a spinning coin. While the coin is spinning, it is in a state of **superposition**—it is both heads and tails at the same time.\n*   Mathematically, a qubit exists in a linear combination of states $|0\\rangle$ and $|1\\rangle$.\n*   This allows quantum computers to process a massive amount of possibilities simultaneously.\n\n### 2. Entanglement\nEntanglement is what Albert Einstein called "spooky action at a distance." It is a phenomenon where two qubits become linked so that the state of one instantly influences the state of the other, no matter how far apart they are.\n*   If you have two entangled qubits and measure one to be "0," the other will immediately be "0" (or "1", depending on the setup), even if it’s on the other side of the universe.\n*   This allows for high-speed coordination and is the key to quantum "teleportation" of information.\n\n### 3. Interference\nQuantum algorithms use interference to manipulate the probability of certain outcomes. \n*   **Constructive interference** amplifies the correct answers.\n*   **Destructive interference** cancels out the wrong answers.\n*   By the end of a calculation, the "noise" has been canceled out, leaving only the correct solution to be measured.\n\n### 4. Measurement (The Collapse)\nThis is the most counterintuitive part of qubit theory. Even though a qubit exists in superposition during a calculation, the moment you **measure** it, it "collapses" into a definite state: either 0 or 1.\n*   You cannot see a qubit in superposition; you can only see the result of its collapse.\n*   Quantum computing is about managing these probabilities so that when the collapse happens, you get the right answer.\n\n### 5. The Bloch Sphere\nScientists visualize a single qubit using a geometric representation called the **Bloch Sphere**. \n*   The "North Pole" is state $|0\\rangle$.\n*   The "South Pole" is state $|1\\rangle$.\n*   A qubit can be a point anywhere on the surface of the sphere. The latitude and longitude represent the specific "mix" of 0 and 1.\n\n---\n\n### Why is this theory so important?\nThe power of qubits scales **exponentially**, not linearly:\n*   **2 bits** can represent 1 of 4 values ($00, 01, 10, 11$).\n*   **2 qubits** can represent all 4 values *at the same time*.\n*   **300 qubits** can represent more states than there are atoms in the observable universe.\n\n### Physical Implementation\nQubits aren\'t just abstract math; they are made from physical systems such as:\n*   **Superconducting loops:** (Used by IBM and Google).\n*   **Trapped Ions:** Using lasers to hold individual atoms in place.\n*   **Photons:** Using particles of light.\n\n**Summary:** Qubit theory is the foundation of quantum computing. By leveraging superposition and entanglement, it allows us to solve problems in chemistry, cryptography, and artificial intelligence that would take classical computers billions of years to compute.'

# %%
from langchain_anthropic import ChatAnthropic

model = ChatAnthropic(
    api_key=os.getenv("ANTHROPIC_API_KEY"),
    model="claude-sonnet-5"
    )

model.invoke("De Brogiile euqatoin and quantum relation").content
# Out:
# "# De Broglie Equation and Quantum Relations\n\n## De Broglie Equation\n\nThe de Broglie equation describes the **wave-particle duality** of matter, proposing that every moving particle has an associated wavelength.\n\n$$\\lambda = \\frac{h}{p} = \\frac{h}{mv}$$\n\n**Where:**\n- λ = de Broglie wavelength\n- h = Planck's constant (6.626 × 10⁻³⁴ J·s)\n- p = momentum of the particle\n- m = mass of the particle\n- v = velocity of the particle\n\n---\n\n## Key Quantum Relations\n\n### 1. **Planck's Equation (Energy of a Photon)**\n$$E = h\\nu = \\frac{hc}{\\lambda}$$\n\n### 2. **Momentum-Wavelength Relation**\n$$p = \\frac{h}{\\lambda}$$\n\n### 3. **De Broglie Wavelength in Terms of Kinetic Energy**\nSince $KE = \\frac{p^2}{2m}$, we get:\n\n$$\\lambda = \\frac{h}{\\sqrt{2mKE}}$$\n\n### 4. **De Broglie Wavelength for a Charged Particle (accelerated through potential V)**\nFor a charge *q* accelerated through potential difference V:\n\n$$KE = qV \\implies \\lambda = \\frac{h}{\\sqrt{2mqV}}$$\n\nFor an **electron**:\n$$\\lambda = \\frac{h}{\\sqrt{2meV}} = \\frac{12.27}{\\sqrt{V}} \\text{ Å}$$\n\n### 5. **De Broglie Wavelength and Bohr's Angular Momentum**\n\nDe Broglie's hypothesis explains Bohr's quantization condition:\n\n$$2\\pi r = n\\lambda \\implies mvr = \\frac{nh}{2\\pi}$$\n\nThis shows that an electron's orbit must accommodate a **whole number of wavelengths** — connecting wave mechanics to Bohr's atomic model.\n\n---\n\n## Summary Table\n\n| Quantity | Formula |\n|----------|---------|\n| Wavelength | λ = h/mv |\n| Momentum | p = h/λ |\n| Energy (photon) | E = hc/λ |\n| Energy (matter wave) | E = p²/2m |\n| Angular momentum (Bohr) | mvr = nh/2π |\n\n---\n\n**Would you like me to:**\n- Derive de Broglie's equation from Einstein's mass-energy relation?\n- Solve a numerical problem using this equation?\n- Explain the experimental verification (Davisson-Germer experiment)?"
