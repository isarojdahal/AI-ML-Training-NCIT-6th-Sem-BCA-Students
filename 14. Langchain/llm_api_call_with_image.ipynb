# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv
import os


load_dotenv()

model = ChatGoogleGenerativeAI(
    api_key=os.getenv("GOOGLE_API_KEY"),
    model="gemini-3.5-flash"
    )

# %%
from langchain_core.messages import HumanMessage
import base64 
with open("image.png", "rb") as image_file:
    img_str = base64.b64encode(image_file.read()).decode("utf-8")

# Prepare multimodal message
message = HumanMessage(
    content=[
        {"type": "text", "text": "Tell me about the image"},
        {
            "type": "image_url",
            "image_url": {"url": f"data:image/png;base64,{img_str}"},
        },
    ]
)
response = model.invoke([message])
print(response.content)
# Out:
# [{'type': 'text', 'text': 'This image shows the famous **Equestrian Statue of Marcus Aurelius**, an ancient Roman bronze monument dating back to approximately 175 AD. \n\nHere is a detailed breakdown of what the image depicts, its artistic features, and its historical significance:\n\n### 1. Visual Description\n* **The Figure (Marcus Aurelius):** The Roman Emperor and Stoic philosopher is shown riding astride. He is depicted with a full beard and curly hair, which was the fashionable style for philosophers and emperors of his era. He does not wear military armor; instead, he wears a tunic and a heavy civilian cloak (*paludamentum*), portraying him as a peaceful ruler and lawmaker rather than a conquering general.\n* **The Gesture:** His right arm is outstretched in a gesture known as *adlocutio* (addressing his troops or citizens) or *clemency* (offering mercy to defeated enemies). \n* **The Horse:** The horse is depicted with remarkable anatomical accuracy, showing realistic muscle definition, veins, and a flowing mane. Its right front leg is raised, and its head is turned slightly with an open mouth and flared nostrils, giving the animal a sense of dynamic movement and energy.\n* **Composition:** The photograph is taken from a low angle, looking upward against a clear, solid blue sky. This perspective emphasizes the monumental scale, grandeur, and authority of the emperor. The bronze material has a rich, weathered patina with warm golden-brown highlights from the sunlight.\n\n### 2. Historical Significance\n* **The Only Survivor:** This is the only fully surviving bronze equestrian statue of a pre-Christian Roman emperor. During the Middle Ages, almost all other bronze statues of Roman pagan emperors were melted down so the metal could be reused for coins or church bells. \n* **Mistaken Identity:** This statue survived only because of a case of mistaken identity. Medieval Christians believed the statue depicted **Constantine the Great**, the first Roman emperor to convert to Christianity. Because Constantine was highly revered, the statue was protected rather than destroyed.\n* **The Location:** For centuries, the original statue stood in the Piazza del Campidoglio (Capitol Square) in Rome, on a pedestal designed by Michelangelo. To protect it from air pollution and weather damage, the original bronze was moved indoors to the Capitoline Museums in 1981, and a highly precise modern replica now stands in the outdoor square. This photo is likely of the outdoor replica against the Roman sky.', 'extras': {'signature': '...'}}]
