# %%
import pandas as pd 

pd.Series([1,2,3])
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
pd.Series([1,2,3],index=["Bibek","Saugat","Kritika"])
# Out:
# Bibek      1
# Saugat     2
# Kritika    3
# dtype: int64

# %%
data = {
    "names":["Bibek","Saugat","Kritika","Adarsha","Saugat","Prasanna","Rashida","Mandip"],
    'diabetes':[4.0,3.9,3.9,3.3,4.0,3.8,3.9,None]
}

print(data)

df = pd.DataFrame(data)

print(df)
# Out:
# {'names': ['Bibek', 'Saugat', 'Kritika', 'Adarsha', 'Saugat', 'Prasanna', 'Rashida', 'Mandip'], 'diabetes': [4.0, 3.9, 3.9, 3.3, 4.0, 3.8, 3.9, None]}
#       names  diabetes
# 0     Bibek       4.0
# 1    Saugat       3.9
# 2   Kritika       3.9
# 3   Adarsha       3.3
# 4    Saugat       4.0
# 5  Prasanna       3.8
# 6   Rashida       3.9
# 7    Mandip       NaN

# %%
df.head()
# Out:
#      names  diabetes
# 0    Bibek       4.0
# 1   Saugat       3.9
# 2  Kritika       3.9
# 3  Adarsha       3.3
# 4   Saugat       4.0

# %%
df.head(3)
# Out:
#      names  diabetes
# 0    Bibek       4.0
# 1   Saugat       3.9
# 2  Kritika       3.9

# %%
df.tail()
# Out:
#       names  diabetes
# 3   Adarsha       3.3
# 4    Saugat       4.0
# 5  Prasanna       3.8
# 6   Rashida       3.9
# 7    Mandip       NaN

# %%
df.tail(3)
# Out:
#       names  diabetes
# 5  Prasanna       3.8
# 6   Rashida       3.9
# 7    Mandip       NaN

# %%
df.shape
# Out:
# (8, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   names     8 non-null      object
#  1   diabetes  7 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 256.0+ bytes

# %%
df["diabetes"].describe()
# Out:
# count    7.000000
# mean     3.828571
# std      0.242997
# min      3.300000
# 25%      3.850000
# 50%      3.900000
# 75%      3.950000
# max      4.000000
# Name: diabetes, dtype: float64

# %%
df["names"]
# Out:
# 0       Bibek
# 1      Saugat
# 2     Kritika
# 3     Adarsha
# 4      Saugat
# 5    Prasanna
# 6     Rashida
# 7      Mandip
# Name: names, dtype: object

# %%
df
# Out:
#       names  diabetes
# 0     Bibek       4.0
# 1    Saugat       3.9
# 2   Kritika       3.9
# 3   Adarsha       3.3
# 4    Saugat       4.0
# 5  Prasanna       3.8
# 6   Rashida       3.9
# 7    Mandip       NaN

# %%
df = df.fillna(3.0)
df
# Out:
#       names  diabetes
# 0     Bibek       4.0
# 1    Saugat       3.9
# 2   Kritika       3.9
# 3   Adarsha       3.3
# 4    Saugat       4.0
# 5  Prasanna       3.8
# 6   Rashida       3.9
# 7    Mandip       3.0

# %%
df = df.dropna()
df
# Out:
#       names  diabetes
# 0     Bibek       4.0
# 1    Saugat       3.9
# 2   Kritika       3.9
# 3   Adarsha       3.3
# 4    Saugat       4.0
# 5  Prasanna       3.8
# 6   Rashida       3.9
# 7    Mandip       3.0

# %%
# df.filter()
# iloc
# loc
# groupby

# %%
# Seaborn

import seaborn as sns 

tips = sns.load_dataset("tips")
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
import matplotlib.pyplot as plt 

sns.scatterplot(data=tips, x="total_bill", y="tip",color="orange")
plt.savefig("plot.png")

# %%
df = pd.DataFrame( {
    "names":["Bibek","Saugat","Kritika","Adarsha","Saugat","Prasanna","Rashida","Mandip"],
    'diabetes':[4.0,3.9,3.9,3.3,4.0,3.8,3.9,None]
})

sns.barplot(data=df,x='names',y='diabetes')
# Out:
# <Axes: xlabel='names', ylabel='diabetes'>
